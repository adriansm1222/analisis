# %% [markdown]
# <a href="https://colab.research.google.com/github/adriansm1222/analisis/blob/main/Mapas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
from folium.plugins import minimap
from folium.plugins import MiniMap
from branca.element import Figure

# %%
CR = folium.Map(location=[9.927589467405527, -84.09343877665742], zoom_start=9, tiles='stamenterrain')

popup = '<b>Sede Central<b>'
folium.Marker(location=[9.99881278711633, -84.111467464084], popup=popup, icon=folium.Icon(color='orange', icon='ok-sign')).add_to(CR)
folium.Circle(location=[9.99881278711633, -84.111467464084], color='purple', weight=6, fill_color='red', fill_opacity=0.5, tooltip='UNA - Sede Central').add_to(CR)

popup = '<b>Campus Benjamín Núñez<b>'
folium.Marker(location=[9.969839928583335, -84.12900478262364], popup=popup, icon=folium.Icon(color='orange', icon='ok-sign')).add_to(CR)
folium.Circle(location=[9.969839928583335, -84.12900478262364], color='purple', weight=6, fill_color='red', fill_opacity=0.5, tooltip='Campus Benjamín Núñez').add_to(CR)

popup = '<b>Sede Interuniversitaria<b>'
folium.Marker(location=[10.019575391588683, -84.19729354974415], popup=popup, icon=folium.Icon(color='orange', icon='ok-sign')).add_to(CR)
folium.Circle(location=[10.019575391588683, -84.19729354974415], color='purple', weight=6, fill_color='red', fill_opacity=0.5, tooltip='Sede Interuniversitaria').add_to(CR)

popup = '<b>Sede Regional Brunca<b>'
folium.Marker(location=[9.3798627007414, -83.69154639015031], popup=popup, icon=folium.Icon(color='orange', icon='ok-sign')).add_to(CR)
folium.Circle(location=[9.3798627007414, -83.69154639015031], color='purple', weight=6, fill_color='red', fill_opacity=0.5, tooltip='Sede Regional Brunca').add_to(CR)

popup = '<b>Campus Liberia<b>'
folium.Marker(location=[10.617665022335068, -85.45088155818432], popup=popup, icon=folium.Icon(color='orange', icon='ok-sign')).add_to(CR)
folium.Circle(location=[10.617665022335068, -85.45088155818432], color='purple', weight=6, fill_color='red', fill_opacity=0.5, tooltip='Campus Liberia').add_to(CR)

minimap = MiniMap(tile_layer='stamenterrain', position='bottomright')

CR.add_child(minimap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
